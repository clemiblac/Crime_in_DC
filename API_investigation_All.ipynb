# %%
#Import dependencies
import requests
import json
import pandas as pd

# %%
list_measurement="https://api.ooni.io/api/v1/measurements"

# %% [markdown]
# #### USA

# %%
url="https://api.ooni.io/api/v1/measurements?probe_cc=US&since=2020-08-26&limit=300"
response=requests.get(url).json()

# %%
print(json.dumps(response,indent=4,sort_keys=True))

# %%
us=response['results']

# %%
data=pd.DataFrame(us)

# %%
data

# %%
data.to_csv('csv_output/08-26/usa_08_26.csv')

# %%
min(data['measurement_start_time'])

# %% [markdown]
# #### CHINA

# %%
url="https://api.ooni.io/api/v1/measurements?probe_cc=CN&since=2020-08-26&limit=300"
response=requests.get(url).json()

# %%
print(json.dumps(response,indent=4,sort_keys=True))
# Out:
# {
#     "metadata": {
#         "count": 17,
#         "current_page": 1,
#         "limit": 300,
#         "next_url": null,
#         "offset": 0,
#         "pages": 1,
#         "query_time": 0.3561422824859619
#     },
#     "results": [
#         {
#             "anomaly": true,
#             "confirmed": false,
#             "failure": false,
#             "input": "http://www.beer.com/",
#             "measurement_id": "temp-fid-0057f1d0a981aef822e39e9a98512dc0",
#             "measurement_start_time": "2020-08-26T12:52:56Z",
#             "measurement_url": "https://api.ooni.io/api/v1/measurement/temp-fid-0057f1d0a981aef822e39e9a98512dc0",
#             "probe_asn": "AS24139",
#             "probe_cc": "CN",
#             "report_id": "20200826T125204Z_AS24139_alOjUqPSpWRQVdlCYj8s0XHld9u8Gum1y7wvQsun7YYJhOKesQ",
#             "scores": {
#                 "analysis": {
#                     "blocking_type": "tcp_ip"
#                 },
#                 "blocking_country": 0.0,
#                 "blocking_general": 1.0,
#                 "blocking_global": 0.0,
#                 "blocking_isp": 0.0,
#                 "blocking_local": 0.0
#             },
#             "test_name": "web_connectivity"
#         },
#         {
#             "anomaly": false,
#             "confirmed": false,
#             "failure": false,
#             "input": "http://www.granma.cu/",
#             "measurement_id": "temp-fid-003920e4ccfea41c64d3c497e90f151d",
#             "measurement_start_time": "2020-08-26T12:52:50Z",
#             "measurement_url": "https://api.ooni.io/api/v1/measurement/temp-fid-003920e4ccfea41c64d3c497e90f151d",
#             "probe_asn": "AS24139",
#             "probe_cc": "CN",
#             "report_id": "20200826T125204Z_AS24139_alOjUqPSpWRQVdlCYj8s0XHld9u8Gum1y7wvQsun7YYJhOKesQ",
#             "scores": {
#                 "blocking_country": 0.0,
#                 "blocking_general": 0.0,
#                 "blocking_global": 0.0,
#                 "blocking_isp": 0.0,
#                 "blocking_local": 0.0
#             },
#             "test_name": "web_connectivity"
#         },
#         {
#             "anomaly": false,
#             "confirmed": false,
#             "failure": false,
#             "input": "http://www.advocate.com/",
#             "measurement_id": "temp-fid-001c6696817ad231c7dc7bbc6814f800",
#             "measurement_start_time": "2020-08-26T12:52:49Z",
#             "measurement_url": "https://api.ooni.io/api/v1/measurement/temp-fid-001c6696817ad231c7dc7bbc6814f800",
#             "probe_asn": "AS24139",
#             "probe_cc": "CN",
#             "report_id": "20200826T125204Z_AS24139_alOjUqPSpWRQVdlCYj8s0XHld9u8Gum1y7wvQsun7YYJhOKesQ",
#             "scores": {
#                 "blocking_country": 0.0,
#                 "blocking_general": 0.0,
#                 "blocking_global": 0.0,
#                 "blocking_isp": 0.0,
#                 "blocking_local": 0.0
#             },
#             "test_name": "web_connectivity"
#         },
#         {
#             "anomaly": false,
#             "confirmed": false,
#             "failure": false,
#             "input": "http://www.gayhealth.com/",
#             "measurement_id": "temp-fid-004c4dd646787f595673362745bf0797",
#             "measurement_start_time": "2020-08-26T12:52:40Z",
#             "measurement_url": "https://api.ooni.io/api/v1/measurement/temp-fid-004c4dd646787f595673362745bf0797",
#             "probe_asn": "AS24139",
#             "probe_cc": "CN",
#             "report_id": "20200826T125204Z_AS24139_alOjUqPSpWRQVdlCYj8s0XHld9u8Gum1y7wvQsun7YYJhOKesQ",
#             "scores": {
#                 "blocking_country": 0.0,
#                 "blocking_general": 0.0,
#                 "blocking_global": 0.0,
#                 "blocking_isp": 0.0,
#                 "blocking_local": 0.0
#             },
#             "test_name": "web_connectivity"
#         },
#         {
#             "anomaly": false,
#             "confirmed": false,
#             "failure": false,
#             "input": "http://www.15880.com/",
#             "measurement_id": "temp-fid-00530715da38d378aef4df21ccc7b6e3",
#             "measurement_start_time": "2020-08-26T12:52:39Z",
#             "measurement_url": "https://api.ooni.io/api/v1/measurement/temp-fid-00530715da38d378aef4df21ccc7b6e3",
#             "probe_asn": "AS24139",
#             "probe_cc": "CN",
#             "report_id": "20200826T125204Z_AS24139_alOjUqPSpWRQVdlCYj8s0XHld9u8Gum1y7wvQsun7YYJhOKesQ",
#             "scores": {
#                 "blocking_country": 0.0,
#                 "blocking_general": 0.0,
#                 "blocking_global": 0.0,
#                 "blocking_isp": 0.0,
#                 "blocking_local": 0.0
#             },
#             "test_name": "web_connectivity"
#         },
#         {
#             "anomaly": true,
#             "confirmed": false,
#             "failure": false,
#             "input": "http://www.navy.mil/",
#             "measurement_id": "temp-fid-00075371dd4b1e127699cf9d711d8192",
#             "measurement_start_time": "2020-08-26T12:52:32Z",
#             "measurement_url": "https://api.ooni.io/api/v1/measurement/temp-fid-00075371dd4b1e127699cf9d711d8192",
#             "probe_asn": "AS24139",
#             "probe_cc": "CN",
#             "report_id": "20200826T125204Z_AS24139_alOjUqPSpWRQVdlCYj8s0XHld9u8Gum1y7wvQsun7YYJhOKesQ",
#             "scores": {
#                 "analysis": {
#                     "blocking_type": "dns"
#                 },
#                 "blocking_country": 0.0,
#                 "blocking_general": 1.0,
#                 "blocking_global": 0.0,
#                 "blocking_isp": 0.0,
#                 "blocking_local": 0.0
#             },
#             "test_name": "web_connectivity"
#         },
#         {
#             "anomaly": false,
#             "confirmed": false,
#             "failure": false,
#             "input": "http://www.topcities.com/",
#             "measurement_id": "temp-fid-0026f1289a70b6a5cb96f277416378a7",
#             "measurement_start_time": "2020-08-26T12:52:24Z",
#             "measurement_url": "https://api.ooni.io/api/v1/measurement/temp-fid-0026f1289a70b6a5cb96f277416378a7",
#             "probe_asn": "AS24139",
#             "probe_cc": "CN",
#             "report_id": "20200826T125204Z_AS24139_alOjUqPSpWRQVdlCYj8s0XHld9u8Gum1y7wvQsun7YYJhOKesQ",
#             "scores": {
#                 "blocking_country": 0.0,
#                 "blocking_general": 0.0,
#                 "blocking_global": 0.0,
#                 "blocking_isp": 0.0,
#                 "blocking_local": 0.0
#             },
#             "test_name": "web_connectivity"
#         },
#         {
#             "anomaly": false,
#             "confirmed": false,
#             "failure": false,
#             "input": "http://hackers.com/",
#             "measurement_id": "temp-fid-00ed215ec0f915e8c9da4045e67d3e82",
#             "measurement_start_time": "2020-08-26T12:52:22Z",
#             "measurement_url": "https://api.ooni.io/api/v1/measurement/temp-fid-00ed215ec0f915e8c9da4045e67d3e82",
#             "probe_asn": "AS24139",
#             "probe_cc": "CN",
#             "report_id": "20200826T125204Z_AS24139_alOjUqPSpWRQVdlCYj8s0XHld9u8Gum1y7wvQsun7YYJhOKesQ",
#             "scores": {
#                 "blocking_country": 0.0,
#                 "blocking_general": 0.0,
#                 "blocking_global": 0.0,
#                 "blocking_isp": 0.0,
#                 "blocking_local": 0.0
#             },
#             "test_name": "web_connectivity"
#         },
#         {
#             "anomaly": true,
#             "confirmed": false,
#             "failure": false,
#             "input": "https://en.wiktionary.org/wiki/Wiktionary:Main_Page/",
#             "measurement_id": "temp-fid-007c622f12911ccccf60155360fb139a",
#             "measurement_start_time": "2020-08-26T12:52:19Z",
#             "measurement_url": "https://api.ooni.io/api/v1/measurement/temp-fid-007c622f12911ccccf60155360fb139a",
#             "probe_asn": "AS24139",
#             "probe_cc": "CN",
#             "report_id": "20200826T125204Z_AS24139_alOjUqPSpWRQVdlCYj8s0XHld9u8Gum1y7wvQsun7YYJhOKesQ",
#             "scores": {
#                 "analysis": {
#                     "blocking_type": "tcp_ip"
#                 },
#                 "blocking_country": 0.0,
#                 "blocking_general": 1.0,
#                 "blocking_global": 0.0,
#                 "blocking_isp": 0.0,
#                 "blocking_local": 0.0
#             },
#             "test_name": "web_connectivity"
#         },
#         {
#             "anomaly": true,
#             "confirmed": false,
#             "failure": false,
#             "input": "http://adultfriendfinder.com/",
#             "measurement_id": "temp-fid-007b9ae0a593aa0734d3e3c6fb8b7098",
#             "measurement_start_time": "2020-08-26T12:52:05Z",
#             "measurement_url": "https://api.ooni.io/api/v1/measurement/temp-fid-007b9ae0a593aa0734d3e3c6fb8b7098",
#             "probe_asn": "AS24139",
#             "probe_cc": "CN",
#             "report_id": "20200826T125204Z_AS24139_alOjUqPSpWRQVdlCYj8s0XHld9u8Gum1y7wvQsun7YYJhOKesQ",
#             "scores": {
#                 "analysis": {
#                     "blocking_type": "tcp_ip"
#                 },
#                 "blocking_country": 0.0,
#                 "blocking_general": 1.0,
#                 "blocking_global": 0.0,
#                 "blocking_isp": 0.0,
#                 "blocking_local": 0.0
#             },
#             "test_name": "web_connectivity"
#         },
#         {
#             "anomaly": false,
#             "confirmed": false,
#             "failure": false,
#             "input": "http://www.meaphone.com/",
#             "measurement_id": "temp-fid-00704aa934336cc3ba4d9ae2f8a334ee",
#             "measurement_start_time": "2020-08-26T12:52:05Z",
#             "measurement_url": "https://api.ooni.io/api/v1/measurement/temp-fid-00704aa934336cc3ba4d9ae2f8a334ee",
#             "probe_asn": "AS24139",
#             "probe_cc": "CN",
#             "report_id": "20200826T125204Z_AS24139_alOjUqPSpWRQVdlCYj8s0XHld9u8Gum1y7wvQsun7YYJhOKesQ",
#             "scores": {
#                 "blocking_country": 0.0,
#                 "blocking_general": 0.0,
#                 "blocking_global": 0.0,
#                 "blocking_isp": 0.0,
#                 "blocking_local": 0.0
#             },
#             "test_name": "web_connectivity"
#         },
#         {
#             "anomaly": false,
#             "confirmed": false,
#             "failure": false,
#             "input": "http://www.medecinsdumonde.org/",
#             "measurement_id": "temp-fid-004005222cc9a1922235b015eebc236b",
#             "measurement_start_time": "2020-08-26T12:52:05Z",
#             "measurement_url": "https://api.ooni.io/api/v1/measurement/temp-fid-004005222cc9a1922235b015eebc236b",
#             "probe_asn": "AS24139",
#             "probe_cc": "CN",
#             "report_id": "20200826T125204Z_AS24139_alOjUqPSpWRQVdlCYj8s0XHld9u8Gum1y7wvQsun7YYJhOKesQ",
#             "scores": {
#                 "blocking_country": 0.0,
#                 "blocking_general": 0.0,
#                 "blocking_global": 0.0,
#                 "blocking_isp": 0.0,
#                 "blocking_local": 0.0
#             },
#             "test_name": "web_connectivity"
#         },
#         {
#             "anomaly": false,
#             "confirmed": false,
#             "failure": false,
#             "input": null,
#             "measurement_id": "temp-fid-0026085298a178d45bfe4979bbdb2b6e",
#             "measurement_start_time": "2020-08-26T07:12:42Z",
#             "measurement_url": "https://api.ooni.io/api/v1/measurement/temp-fid-0026085298a178d45bfe4979bbdb2b6e",
#             "probe_asn": "AS4808",
#             "probe_cc": "CN",
#             "report_id": "20200826T071243Z_AS4808_5pybE2SLVfqTVuBklaNz4ZSq7qQQE5nzngEPffughuXCLMsQqy",
#             "scores": {
#                 "blocking_country": 0.0,
#                 "blocking_general": 0.0,
#                 "blocking_global": 0.0,
#                 "blocking_isp": 0.0,
#                 "blocking_local": 0.0
#             },
#             "test_name": "http_invalid_request_line"
#         },
#         {
#             "anomaly": false,
#             "confirmed": false,
#             "failure": false,
#             "input": null,
#             "measurement_id": "temp-fid-00dede06cb505a90fe63e35b1a49148e",
#             "measurement_start_time": "2020-08-26T07:12:30Z",
#             "measurement_url": "https://api.ooni.io/api/v1/measurement/temp-fid-00dede06cb505a90fe63e35b1a49148e",
#             "probe_asn": "AS4808",
#             "probe_cc": "CN",
#             "report_id": "20200826T071231Z_AS4808_DdKlfuTWLHvUGZZns2tP8Hr8wmer0c0FHIY2HxedrByTtB9c0t",
#             "scores": {
#                 "blocking_country": 0.0,
#                 "blocking_general": 0.0,
#                 "blocking_global": 0.0,
#                 "blocking_isp": 0.0,
#                 "blocking_local": 0.0
#             },
#             "test_name": "http_header_field_manipulation"
#         },
#         {
#             "anomaly": false,
#             "confirmed": false,
#             "failure": true,
#             "input": null,
#             "measurement_id": "temp-fid-002a06a1ae557d44739fca54d80e334d",
#             "measurement_start_time": "2020-08-26T07:10:17Z",
#             "measurement_url": "https://api.ooni.io/api/v1/measurement/temp-fid-002a06a1ae557d44739fca54d80e334d",
#             "probe_asn": "AS4808",
#             "probe_cc": "CN",
#             "report_id": "20200826T071018Z_AS4808_XjGYsOPhuh4cFE39ej8qhiekJYvIm6srZGl3Xjqn2dUYTthcn5",
#             "scores": {
#                 "accuracy": 0.0,
#                 "blocking_country": 0.0,
#                 "blocking_general": 0.0,
#                 "blocking_global": 0.0,
#                 "blocking_isp": 0.0,
#                 "blocking_local": 0.0,
#                 "msg": "Probe error"
#             },
#             "test_name": "dash"
#         },
#         {
#             "anomaly": false,
#             "confirmed": false,
#             "failure": false,
#             "input": null,
#             "measurement_id": "temp-fid-00a3d8c1a61f82c084d199bb5f24ea9b",
#             "measurement_start_time": "2020-08-26T07:09:44Z",
#             "measurement_url": "https://api.ooni.io/api/v1/measurement/temp-fid-00a3d8c1a61f82c084d199bb5f24ea9b",
#             "probe_asn": "AS4808",
#             "probe_cc": "CN",
#             "report_id": "20200826T070945Z_AS4808_jVufEoJjXZE5YbKlyBZ2CKHItLR5r6xdyBe9KCkjEm6pdayYTq",
#             "scores": {},
#             "test_name": "ndt"
#         },
#         {
#             "anomaly": false,
#             "confirmed": false,
#             "failure": false,
#             "input": null,
#             "measurement_id": "temp-fid-00e05c9f54ecf1e295392309f19b2e1b",
#             "measurement_start_time": "2020-08-26T06:49:48Z",
#             "measurement_url": "https://api.ooni.io/api/v1/measurement/temp-fid-00e05c9f54ecf1e295392309f19b2e1b",
#             "probe_asn": "AS0",
#             "probe_cc": "CN",
#             "report_id": "20200826T064947Z_AS0_GK9mANG7DBiRfW60F9waGR8MfBwZovfQcp776r5wFmdXky976J",
#             "scores": {},
#             "test_name": "ndt"
#         }
#     ]
# }

# %%
china=response['results']

# %%
data=pd.DataFrame(china)

# %%
data
# Out:
#     anomaly  confirmed  failure  \
# 0      True      False    False
# 1     False      False    False
# 2     False      False    False
# 3     False      False    False
# 4     False      False    False
# 5      True      False    False
# 6     False      False    False
# 7     False      False    False
# 8      True      False    False
# 9      True      False    False
# 10    False      False    False
# 11    False      False    False
# 12    False      False    False
# 13    False      False    False
# 14    False      False     True
# 15    False      False    False
# 16    False      False    False
#
#                                                 input  \
# 0                                http://www.beer.com/
# 1                               http://www.granma.cu/
# 2                            http://www.advocate.com/
# 3                           http://www.gayhealth.com/
# 4                               http://www.15880.com/
# 5                                http://www.navy.mil/
# 6                           http://www.topcities.com/
# 7                                 http://hackers.com/
# 8   https://en.wiktionary.org/wiki/Wiktionary:Main...
# 9                       http://adultfriendfinder.com/
# 10                           http://www.meaphone.com/
# 11                    http://www.medecinsdumonde.org/
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
#
#                                measurement_id measurement_start_time  \
# 0   temp-fid-0057f1d0a981aef822e39e9a98512dc0   2020-08-26T12:52:56Z
# 1   temp-fid-003920e4ccfea41c64d3c497e90f151d   2020-08-26T12:52:50Z
# 2   temp-fid-001c6696817ad231c7dc7bbc6814f800   2020-08-26T12:52:49Z
# 3   temp-fid-004c4dd646787f595673362745bf0797   2020-08-26T12:52:40Z
# 4   temp-fid-00530715da38d378aef4df21ccc7b6e3   2020-08-26T12:52:39Z
# 5   temp-fid-00075371dd4b1e127699cf9d711d8192   2020-08-26T12:52:32Z
# 6   temp-fid-0026f1289a70b6a5cb96f277416378a7   2020-08-26T12:52:24Z
# 7   temp-fid-00ed215ec0f915e8c9da4045e67d3e82   2020-08-26T12:52:22Z
# 8   temp-fid-007c622f12911ccccf60155360fb139a   2020-08-26T12:52:19Z
# 9   temp-fid-007b9ae0a593aa0734d3e3c6fb8b7098   2020-08-26T12:52:05Z
# 10  temp-fid-00704aa934336cc3ba4d9ae2f8a334ee   2020-08-26T12:52:05Z
# 11  temp-fid-004005222cc9a1922235b015eebc236b   2020-08-26T12:52:05Z
# 12  temp-fid-0026085298a178d45bfe4979bbdb2b6e   2020-08-26T07:12:42Z
# 13  temp-fid-00dede06cb505a90fe63e35b1a49148e   2020-08-26T07:12:30Z
# 14  temp-fid-002a06a1ae557d44739fca54d80e334d   2020-08-26T07:10:17Z
# 15  temp-fid-00a3d8c1a61f82c084d199bb5f24ea9b   2020-08-26T07:09:44Z
# 16  temp-fid-00e05c9f54ecf1e295392309f19b2e1b   2020-08-26T06:49:48Z
#
#                                       measurement_url probe_asn probe_cc  \
# 0   https://api.ooni.io/api/v1/measurement/temp-fi...   AS24139       CN
# 1   https://api.ooni.io/api/v1/measurement/temp-fi...   AS24139       CN
# 2   https://api.ooni.io/api/v1/measurement/temp-fi...   AS24139       CN
# 3   https://api.ooni.io/api/v1/measurement/temp-fi...   AS24139       CN
# 4   https://api.ooni.io/api/v1/measurement/temp-fi...   AS24139       CN
# 5   https://api.ooni.io/api/v1/measurement/temp-fi...   AS24139       CN
# 6   https://api.ooni.io/api/v1/measurement/temp-fi...   AS24139       CN
# 7   https://api.ooni.io/api/v1/measurement/temp-fi...   AS24139       CN
# 8   https://api.ooni.io/api/v1/measurement/temp-fi...   AS24139       CN
# 9   https://api.ooni.io/api/v1/measurement/temp-fi...   AS24139       CN
# 10  https://api.ooni.io/api/v1/measurement/temp-fi...   AS24139       CN
# 11  https://api.ooni.io/api/v1/measurement/temp-fi...   AS24139       CN
# 12  https://api.ooni.io/api/v1/measurement/temp-fi...    AS4808       CN
# 13  https://api.ooni.io/api/v1/measurement/temp-fi...    AS4808       CN
# 14  https://api.ooni.io/api/v1/measurement/temp-fi...    AS4808       CN
# 15  https://api.ooni.io/api/v1/measurement/temp-fi...    AS4808       CN
# 16  https://api.ooni.io/api/v1/measurement/temp-fi...       AS0       CN
#
#                                             report_id  \
# 0   20200826T125204Z_AS24139_alOjUqPSpWRQVdlCYj8s0...
# 1   20200826T125204Z_AS24139_alOjUqPSpWRQVdlCYj8s0...
# 2   20200826T125204Z_AS24139_alOjUqPSpWRQVdlCYj8s0...
# 3   20200826T125204Z_AS24139_alOjUqPSpWRQVdlCYj8s0...
# 4   20200826T125204Z_AS24139_alOjUqPSpWRQVdlCYj8s0...
# 5   20200826T125204Z_AS24139_alOjUqPSpWRQVdlCYj8s0...
# 6   20200826T125204Z_AS24139_alOjUqPSpWRQVdlCYj8s0...
# 7   20200826T125204Z_AS24139_alOjUqPSpWRQVdlCYj8s0...
# 8   20200826T125204Z_AS24139_alOjUqPSpWRQVdlCYj8s0...
# 9   20200826T125204Z_AS24139_alOjUqPSpWRQVdlCYj8s0...
# 10  20200826T125204Z_AS24139_alOjUqPSpWRQVdlCYj8s0...
# 11  20200826T125204Z_AS24139_alOjUqPSpWRQVdlCYj8s0...
# 12  20200826T071243Z_AS4808_5pybE2SLVfqTVuBklaNz4Z...
# 13  20200826T071231Z_AS4808_DdKlfuTWLHvUGZZns2tP8H...
# 14  20200826T071018Z_AS4808_XjGYsOPhuh4cFE39ej8qhi...
# 15  20200826T070945Z_AS4808_jVufEoJjXZE5YbKlyBZ2CK...
# 16  20200826T064947Z_AS0_GK9mANG7DBiRfW60F9waGR8Mf...
#
#                                                scores  \
# 0   {'analysis': {'blocking_type': 'tcp_ip'}, 'blo...
# 1   {'blocking_country': 0.0, 'blocking_general': ...
# 2   {'blocking_country': 0.0, 'blocking_general': ...
# 3   {'blocking_country': 0.0, 'blocking_general': ...
# 4   {'blocking_country': 0.0, 'blocking_general': ...
# 5   {'analysis': {'blocking_type': 'dns'}, 'blocki...
# 6   {'blocking_country': 0.0, 'blocking_general': ...
# 7   {'blocking_country': 0.0, 'blocking_general': ...
# 8   {'analysis': {'blocking_type': 'tcp_ip'}, 'blo...
# 9   {'analysis': {'blocking_type': 'tcp_ip'}, 'blo...
# 10  {'blocking_country': 0.0, 'blocking_general': ...
# 11  {'blocking_country': 0.0, 'blocking_general': ...
# 12  {'blocking_country': 0.0, 'blocking_general': ...
# 13  {'blocking_country': 0.0, 'blocking_general': ...
# 14  {'accuracy': 0.0, 'blocking_country': 0.0, 'bl...
# 15                                                 {}
# 16                                                 {}
#
#                          test_name
# 0                 web_connectivity
# 1                 web_connectivity
# 2                 web_connectivity
# 3                 web_connectivity
# 4                 web_connectivity
# 5                 web_connectivity
# 6                 web_connectivity
# 7                 web_connectivity
# 8                 web_connectivity
# 9                 web_connectivity
# 10                web_connectivity
# 11                web_connectivity
# 12       http_invalid_request_line
# 13  http_header_field_manipulation
# 14                            dash
# 15                             ndt
# 16                             ndt

# %%
data.to_csv('csv_output/08-26/china_08_26.csv')

# %% [markdown]
# #### RUSSIA

# %%
url="https://api.ooni.io/api/v1/measurements?probe_cc=RU&since=2020-08-26&limit=300"
response=requests.get(url).json()

# %%
print(json.dumps(response,indent=4,sort_keys=True))

# %%
russia=response['results']

# %%
data=pd.DataFrame(russia)

# %%
data

# %%
data.to_csv('csv_output/08-26/russia_08_26.csv')

# %% [markdown]
# ## Venezuala

# %%
url="https://api.ooni.io/api/v1/measurements?probe_cc=VE&since=2020-08-26&limit=300"
response=requests.get(url).json()

# %%
print(json.dumps(response,indent=4,sort_keys=True))

# %%
venezuela=response['results']

# %%
data=pd.DataFrame(venezuela)

# %%
data

# %%
data.to_csv('csv_output/08-26/venezuela_08_26.csv')

# %% [markdown]
# ## Morocco

# %%
url="https://api.ooni.io/api/v1/measurements?probe_cc=MA&since=2020-08-26&limit=300"
response=requests.get(url).json()

# %%
print(json.dumps(response,indent=4,sort_keys=True))

# %%
morocco=response['results']

# %%
data=pd.DataFrame(morocco)

# %%
data

# %%
data.to_csv('csv_output/08-26/morocco_08_26.csv')
