# %%
#Import dependencies
import requests
import json
import pandas as pd

# %%
list_measurement="https://api.ooni.io/api/v1/measurements"

# %% [markdown]
# #### USA

# %%
url="https://api.ooni.io/api/v1/measurements?probe_cc=US&since=2020-08-30&limit=300"
response=requests.get(url).json()

# %%
print(json.dumps(response,indent=4,sort_keys=True))
# Out:
# {
#     "metadata": {
#         "count": -1,
#         "current_page": 1,
#         "limit": 300,
#         "next_url": "https://api.ooni.io/api/v1/measurements?probe_cc=US&since=2020-08-30&limit=300&offset=300",
#         "offset": 0,
#         "pages": -1,
#         "query_time": 12.427956819534302
#     },
#     "results": [
#         {
#             "anomaly": false,
#             "confirmed": false,
#             "failure": false,
#             "input": null,
#             "measurement_id": "temp-id-436826418",
#             "measurement_start_time": "2020-08-30T17:06:50Z",
#             "measurement_url": "https://api.ooni.io/api/v1/measurement/temp-id-436826418",
#             "probe_asn": "AS0",
#             "probe_cc": "US",
#             "report_id": "20200828T170718Z_AS0_q3VsqXH0HcsLNXwAr1QIoc6lOnKkBFC7VSmWuBDDrbdJyh3ycC",
#             "scores": {},
#             "test_name": "ndt"
#         },
#         {
#             "anomaly": false,
# ...

# %%
us=response['results']

# %%
data=pd.DataFrame(us)

# %%
data
# Out:
#      anomaly  confirmed  failure  \
# 0      False      False    False
# 1      False      False    False
# 2      False      False    False
# 3      False      False    False
# 4      False      False    False
# ..       ...        ...      ...
# 295    False      False    False
# 296    False      False    False
# 297    False      False    False
# 298    False      False    False
# 299    False      False    False
#
#                                                  input  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 295                            https://www.hotbot.com/
# 296                             http://pingomatic.com/
# 297                 http://international.ohmynews.com/
# ...

# %%
data.to_csv('csv_output/08-30/usa_08_30.csv')

# %%
min(data['measurement_start_time'])
# Out:
# '2020-08-30T11:54:33Z'

# %% [markdown]
# #### CHINA

# %%
url="https://api.ooni.io/api/v1/measurements?probe_cc=CN&since=2020-08-30&limit=300"
response=requests.get(url).json()

# %%
print(json.dumps(response,indent=4,sort_keys=True))
# Out:
# {
#     "metadata": {
#         "count": 29,
#         "current_page": 1,
#         "limit": 300,
#         "next_url": null,
#         "offset": 0,
#         "pages": 1,
#         "query_time": 3.2415659427642822
#     },
#     "results": [
#         {
#             "anomaly": false,
#             "confirmed": false,
#             "failure": false,
#             "input": "https://www.reproductiverights.org/",
#             "measurement_id": "temp-fid-008b3651922e6a070d39d56cfee99a4b",
#             "measurement_start_time": "2020-08-30T14:08:39Z",
#             "measurement_url": "https://api.ooni.io/api/v1/measurement/temp-fid-008b3651922e6a070d39d56cfee99a4b",
#             "probe_asn": "AS24547",
#             "probe_cc": "CN",
#             "report_id": "20200830T140748Z_AS24547_UAoZmdHLYUuTxXahp0MKSYl7zSyAbjuaC66Rxa0m4WgUPmwDEe",
#             "scores": {
#                 "blocking_country": 0.0,
#                 "blocking_general": 0.0,
# ...

# %%
china=response['results']

# %%
data=pd.DataFrame(china)

# %%
data
# Out:
#     anomaly  confirmed  failure  \
# 0     False      False    False
# 1      True      False    False
# 2     False      False    False
# 3     False      False    False
# 4      True      False    False
# 5      True      False    False
# 6      True      False    False
# 7      True      False    False
# 8     False      False    False
# 9     False      False    False
# 10    False      False    False
# 11    False      False    False
# 12    False      False    False
# 13    False      False    False
# 14     True      False    False
# 15    False      False    False
# 16    False      False    False
# 17     True      False    False
# 18    False      False    False
# 19    False      False    False
# 20    False      False    False
# 21    False      False    False
# 22    False      False    False
# 23     True      False    False
# 24    False      False    False
# 25     True      False    False
# 26    False      False    False
# 27     True      False    False
# ...

# %%
data.to_csv('csv_output/08-30/china_08_30.csv')

# %% [markdown]
# #### RUSSIA

# %%
url="https://api.ooni.io/api/v1/measurements?probe_cc=RU&since=2020-08-30&limit=300"
response=requests.get(url).json()

# %%
print(json.dumps(response,indent=4,sort_keys=True))
# Out:
# {
#     "metadata": {
#         "count": -1,
#         "current_page": 1,
#         "limit": 300,
#         "next_url": "https://api.ooni.io/api/v1/measurements?probe_cc=RU&since=2020-08-30&limit=300&offset=300",
#         "offset": 0,
#         "pages": -1,
#         "query_time": 9.37417221069336
#     },
#     "results": [
#         {
#             "anomaly": false,
#             "confirmed": false,
#             "failure": false,
#             "input": null,
#             "measurement_id": "temp-fid-00144b3fdcf7b9203cbcb9917721bad3",
#             "measurement_start_time": "2020-08-30T18:20:24Z",
#             "measurement_url": "https://api.ooni.io/api/v1/measurement/temp-fid-00144b3fdcf7b9203cbcb9917721bad3",
#             "probe_asn": "AS31195",
#             "probe_cc": "RU",
#             "report_id": "20200830T111618Z_AS31195_9ZAgpGDQPmwOaQghVyemJ5N73IteCOvs1CMAZjT46RO9huSCkn",
#             "scores": {},
#             "test_name": "ndt"
#         },
#         {
# ...

# %%
russia=response['results']

# %%
data=pd.DataFrame(russia)

# %%
data
# Out:
#      anomaly  confirmed  failure input  \
# 0      False      False    False  None
# 1      False      False    False  None
# 2      False      False    False  None
# 3      False      False    False  None
# 4      False      False    False  None
# ..       ...        ...      ...   ...
# 295    False      False    False  None
# 296    False      False    False  None
# 297    False      False    False  None
# 298    False      False    False  None
# 299    False      False    False  None
#
#                                 measurement_id measurement_start_time  \
# 0    temp-fid-00144b3fdcf7b9203cbcb9917721bad3   2020-08-30T18:20:24Z
# 1    temp-fid-0030b5495f2f5ec12df43b471b42b7b1   2020-08-30T17:41:46Z
# 2    temp-fid-00e2e36e8b68c6c029f177dc68eeb686   2020-08-30T17:41:23Z
# 3    temp-fid-00c697bff236bca1c41b586f2dd71a9b   2020-08-30T17:39:04Z
# 4    temp-fid-005b588bb11998e5a4946b2c39b964ff   2020-08-30T14:29:53Z
# ...

# %%
data.to_csv('csv_output/08-30/russia_08_30.csv')

# %% [markdown]
# ## Venezuala

# %%
url="https://api.ooni.io/api/v1/measurements?probe_cc=VE&since=2020-08-30&limit=300"
response=requests.get(url).json()

# %%
print(json.dumps(response,indent=4,sort_keys=True))
# Out:
# {
#     "metadata": {
#         "count": -1,
#         "current_page": 1,
#         "limit": 300,
#         "next_url": "https://api.ooni.io/api/v1/measurements?probe_cc=VE&since=2020-08-30&limit=300&offset=300",
#         "offset": 0,
#         "pages": -1,
#         "query_time": 0.4563322067260742
#     },
#     "results": [
#         {
#             "anomaly": false,
#             "confirmed": false,
#             "failure": false,
#             "input": null,
#             "measurement_id": "temp-fid-001ce1b1e9178df81f4ca3b90dd06e2d",
#             "measurement_start_time": "2020-08-30T13:47:41Z",
#             "measurement_url": "https://api.ooni.io/api/v1/measurement/temp-fid-001ce1b1e9178df81f4ca3b90dd06e2d",
#             "probe_asn": "AS8048",
#             "probe_cc": "VE",
#             "report_id": "20200830T134741Z_AS8048_utGjsNFRQMi1WlmSZXhwbcqcYjTTh0DDgDKdwcx8hAIHyWKgiE",
#             "scores": {
#                 "blocking_country": 0.0,
# ...

# %%
venezuela=response['results']

# %%
data=pd.DataFrame(venezuela)

# %%
data
# Out:
#      anomaly  confirmed  failure                               input  \
# 0      False      False    False                                None
# 1      False      False    False                                None
# 2      False      False    False                                None
# 3      False      False    False                                None
# 4      False      False    False                                None
# ..       ...        ...      ...                                 ...
# 295    False      False    False  http://proxytools.sourceforge.net/
# 296     True      False    False                 https://psiphon.ca/
# 297    False      False    False                   http://proxy.org/
# 298    False      False    False                https://proxify.com/
# 299    False      False    False               http://peacefire.org/
#
#                                 measurement_id measurement_start_time  \
# ...

# %%
data.to_csv('csv_output/08-30/venezuela_08_30.csv')

# %% [markdown]
# ## Morocco

# %%
url="https://api.ooni.io/api/v1/measurements?probe_cc=MA&since=2020-08-30&limit=300"
response=requests.get(url).json()

# %%
print(json.dumps(response,indent=4,sort_keys=True))
# Out:
# {
#     "metadata": {
#         "count": 86,
#         "current_page": 1,
#         "limit": 300,
#         "next_url": null,
#         "offset": 0,
#         "pages": 1,
#         "query_time": 7.369497537612915
#     },
#     "results": [
#         {
#             "anomaly": false,
#             "confirmed": false,
#             "failure": false,
#             "input": null,
#             "measurement_id": "temp-fid-00a3d143bfc15423d1f5e4a07b4aa791",
#             "measurement_start_time": "2020-08-30T13:47:29Z",
#             "measurement_url": "https://api.ooni.io/api/v1/measurement/temp-fid-00a3d143bfc15423d1f5e4a07b4aa791",
#             "probe_asn": "AS36903",
#             "probe_cc": "MA",
#             "report_id": "20200830T134728Z_AS36903_pLtcNWutMEUG43bCBvbHaQ8H6C5YNPxxe28u8vmALZYwQiEBTI",
#             "scores": {},
#             "test_name": "ndt"
#         },
#         {
#             "anomaly": false,
#             "confirmed": false,
#             "failure": false,
# ...

# %%
morocco=response['results']

# %%
data=pd.DataFrame(morocco)

# %%
data
# Out:
#     anomaly  confirmed  failure input  \
# 0     False      False    False  None
# 1     False      False    False  None
# 2     False      False    False  None
# 3     False      False    False  None
# 4     False      False    False  None
# ..      ...        ...      ...   ...
# 81    False      False    False  None
# 82    False      False    False  None
# 83    False      False    False  None
# 84    False      False    False  None
# 85    False      False    False  None
#
#                                measurement_id measurement_start_time  \
# 0   temp-fid-00a3d143bfc15423d1f5e4a07b4aa791   2020-08-30T13:47:29Z
# 1   temp-fid-00de903b8d6f8226472fcb542f867f35   2020-08-30T13:46:49Z
# 2   temp-fid-002d6971befeaf67d03863811efe8aa2   2020-08-30T13:42:39Z
# 3   temp-fid-0089e4000b3bf0b8f6b4da60d5129649   2020-08-30T13:41:01Z
# 4   temp-fid-00ee93d84d9e1b61088d9064f2884c42   2020-08-30T13:39:37Z
# ..                                        ...                    ...
# ...

# %%
data.to_csv('csv_output/08-30/morocco_08_30.csv')
