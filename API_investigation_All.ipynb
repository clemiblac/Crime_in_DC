# %%
#Import dependencies
import requests
import json
import pandas as pd

# %%
list_measurement="https://api.ooni.io/api/v1/measurements"

# %% [markdown]
# #### USA

# %%
url="https://api.ooni.io/api/v1/measurements?probe_cc=US&since=2020-09-02&limit=300"
response=requests.get(url).json()

# %%
print(json.dumps(response,indent=4,sort_keys=True))
# Out:
# {
#     "metadata": {
#         "count": -1,
#         "current_page": 1,
#         "limit": 300,
#         "next_url": "https://api.ooni.io/api/v1/measurements?probe_cc=US&since=2020-09-02&limit=300&offset=300",
#         "offset": 0,
#         "pages": -1,
#         "query_time": 15.568397521972656
#     },
#     "results": [
#         {
#             "anomaly": false,
#             "confirmed": false,
#             "failure": false,
#             "input": null,
#             "measurement_id": "temp-fid-001762aab83d4e8092fc4b42fbca5743",
#             "measurement_start_time": "2020-09-02T22:59:12Z",
#             "measurement_url": "https://api.ooni.io/api/v1/measurement/temp-fid-001762aab83d4e8092fc4b42fbca5743",
#             "probe_asn": "AS20057",
#             "probe_cc": "US",
#             "report_id": "20200902T225912Z_AS20057_To4UIvcvBD3J4ytEg4goynkPs5lylX2tx5p0892nvBkQPutANZ",
#             "scores": {},
#             "test_name": "ndt"
#         },
#         {
# ...

# %%
us=response['results']

# %%
data=pd.DataFrame(us)

# %%
data
# Out:
#      anomaly  confirmed  failure                            input  \
# 0      False      False    False                             None
# 1      False      False    False                             None
# 2      False      False    False                             None
# 3      False      False    False                             None
# 4      False      False    False                             None
# ..       ...        ...      ...                              ...
# 295    False      False    False               http://www.89.com/
# 296    False      False    False          http://www.foxnews.com/
# 297    False      False    False  https://www.nostraightnews.com/
# 298    False      False    False                             None
# 299    False      False    False                             None
#
#                                 measurement_id measurement_start_time  \
# 0    temp-fid-001762aab83d4e8092fc4b42fbca5743   2020-09-02T22:59:12Z
# ...

# %%
data.to_csv('csv_output/09-02/usa_09_02.csv')

# %%
min(data['measurement_start_time'])
# Out:
# '2020-09-02T20:08:22Z'

# %% [markdown]
# #### CHINA

# %%
url="https://api.ooni.io/api/v1/measurements?probe_cc=CN&since=2020-09-02&limit=300"
response=requests.get(url).json()

# %%
print(json.dumps(response,indent=4,sort_keys=True))
# Out:
# {
#     "metadata": {
#         "count": -1,
#         "current_page": 1,
#         "limit": 300,
#         "next_url": "https://api.ooni.io/api/v1/measurements?probe_cc=CN&since=2020-09-02&limit=300&offset=300",
#         "offset": 0,
#         "pages": -1,
#         "query_time": 0.3402674198150635
#     },
#     "results": [
#         {
#             "anomaly": false,
#             "confirmed": false,
#             "failure": false,
#             "input": null,
#             "measurement_id": "temp-fid-0086f37ed1cfc31d7d77eda8094ccb13",
#             "measurement_start_time": "2020-09-02T14:50:27Z",
#             "measurement_url": "https://api.ooni.io/api/v1/measurement/temp-fid-0086f37ed1cfc31d7d77eda8094ccb13",
#             "probe_asn": "AS0",
#             "probe_cc": "CN",
#             "report_id": "20200902T145028Z_AS0_eghU6WRKZkmhKbvhHGQEAYQhgQJ9PMMvFr3BhjjXnhysnG167Y",
#             "scores": {},
#             "test_name": "ndt"
#         },
#         {
# ...

# %%
china=response['results']

# %%
data=pd.DataFrame(china)

# %%
data
# Out:
#      anomaly  confirmed  failure                                    input  \
# 0      False      False    False                                     None
# 1      False      False    False                                     None
# 2      False      False    False                                     None
# 3      False      False    False                                     None
# 4      False      False    False                                     None
# ..       ...        ...      ...                                      ...
# 295    False      False    False                        https://epic.org/
# 296    False      False    False          https://globalpressjournal.com/
# 297    False      False    False  http://translator.babylon-software.com/
# 298     True      False    False                       https://vimeo.com/
# 299    False      False    False               https://www.article19.org/
#
#                                 measurement_id measurement_start_time  \
# ...

# %%
data.to_csv('csv_output/09-02/china_09_02.csv')

# %% [markdown]
# #### RUSSIA

# %%
url="https://api.ooni.io/api/v1/measurements?probe_cc=RU&since=2020-09-02&limit=300"
response=requests.get(url).json()

# %%
print(json.dumps(response,indent=4,sort_keys=True))
# Out:
# {
#     "metadata": {
#         "count": -1,
#         "current_page": 1,
#         "limit": 300,
#         "next_url": "https://api.ooni.io/api/v1/measurements?probe_cc=RU&since=2020-09-02&limit=300&offset=300",
#         "offset": 0,
#         "pages": -1,
#         "query_time": 8.329512596130371
#     },
#     "results": [
#         {
#             "anomaly": false,
#             "confirmed": false,
#             "failure": false,
#             "input": null,
#             "measurement_id": "temp-fid-00fb4dcaf41cc9cdff0a53fee3118d46",
#             "measurement_start_time": "2020-09-03T09:57:50Z",
#             "measurement_url": "https://api.ooni.io/api/v1/measurement/temp-fid-00fb4dcaf41cc9cdff0a53fee3118d46",
#             "probe_asn": "AS3216",
#             "probe_cc": "RU",
#             "report_id": "20200902T145021Z_AS3216_trs2qULU6KDlQ0WxqtQSkcRFb9iKPBr9268YIQ0dmANMFN0dlU",
#             "scores": {},
#             "test_name": "ndt"
#         },
#         {
# ...

# %%
russia=response['results']

# %%
data=pd.DataFrame(russia)

# %%
data
# Out:
#      anomaly  confirmed  failure input  \
# 0      False      False    False  None
# 1      False      False    False  None
# 2      False      False    False  None
# 3       True      False    False  None
# 4      False      False    False  None
# ..       ...        ...      ...   ...
# 295    False      False    False  None
# 296    False      False    False  None
# 297    False      False    False  None
# 298    False      False    False  None
# 299    False      False    False  None
#
#                                 measurement_id measurement_start_time  \
# 0    temp-fid-00fb4dcaf41cc9cdff0a53fee3118d46   2020-09-03T09:57:50Z
# 1    temp-fid-00c0d69a732928033f73494655f61c2a   2020-09-02T22:31:46Z
# 2    temp-fid-006cb7fbce502ec0f63c5adbde2a21d8   2020-09-02T22:22:52Z
# 3    temp-fid-0002760a72567df5c72f8a97c9e33a79   2020-09-02T22:22:50Z
# 4    temp-fid-0012280fda36e439fd0f5602ecff13a7   2020-09-02T22:22:46Z
# ...

# %%
data.to_csv('csv_output/09-02/russia_09_02.csv')

# %% [markdown]
# ## Venezuala

# %%
url="https://api.ooni.io/api/v1/measurements?probe_cc=VE&since=2020-09-02&limit=300"
response=requests.get(url).json()

# %%
print(json.dumps(response,indent=4,sort_keys=True))
# Out:
# {
#     "metadata": {
#         "count": 122,
#         "current_page": 1,
#         "limit": 300,
#         "next_url": null,
#         "offset": 0,
#         "pages": 1,
#         "query_time": 1.005342721939087
#     },
#     "results": [
#         {
#             "anomaly": false,
#             "confirmed": false,
#             "failure": false,
#             "input": null,
#             "measurement_id": "temp-fid-0093415d86b7602fb8e5e80afb55e62d",
#             "measurement_start_time": "2020-09-03T03:13:50Z",
#             "measurement_url": "https://api.ooni.io/api/v1/measurement/temp-fid-0093415d86b7602fb8e5e80afb55e62d",
#             "probe_asn": "AS8048",
#             "probe_cc": "VE",
#             "report_id": "20200902T151303Z_AS8048_BXb6aYYXQZzi3spTq6I1mMbVayLNn7YAtAVQsHjFk5h6V0eMIE",
#             "scores": {},
#             "test_name": "ndt"
#         },
#         {
#             "anomaly": false,
#             "confirmed": false,
#             "failure": false,
# ...

# %%
venezuela=response['results']

# %%
data=pd.DataFrame(venezuela)

# %%
data
# Out:
#      anomaly  confirmed  failure                                 input  \
# 0      False      False    False                                  None
# 1      False      False    False                                  None
# 2      False      False    False                  https://www.efe.com/
# 3      False      False    False  https://consulta.teleconsultave.com/
# 4      False      False    False            https://presidenciave.org/
# ..       ...        ...      ...                                   ...
# 117    False      False    False                                  None
# 118    False      False    False                                  None
# 119    False      False    False                                  None
# 120    False      False    False                                  None
# 121    False      False    False                                  None
#
#                                 measurement_id measurement_start_time  \
# ...

# %%
data.to_csv('csv_output/09-02/venezuela_09_02.csv')

# %% [markdown]
# ## Morocco

# %%
url="https://api.ooni.io/api/v1/measurements?probe_cc=MA&since=2020-09-02&limit=300"
response=requests.get(url).json()

# %%
print(json.dumps(response,indent=4,sort_keys=True))
# Out:
# {
#     "metadata": {
#         "count": 212,
#         "current_page": 1,
#         "limit": 300,
#         "next_url": null,
#         "offset": 0,
#         "pages": 1,
#         "query_time": 7.682672023773193
#     },
#     "results": [
#         {
#             "anomaly": false,
#             "confirmed": false,
#             "failure": false,
#             "input": null,
#             "measurement_id": "temp-fid-00935f1c416b2f3f4fd93b4e7e265553",
#             "measurement_start_time": "2020-09-02T22:57:29Z",
#             "measurement_url": "https://api.ooni.io/api/v1/measurement/temp-fid-00935f1c416b2f3f4fd93b4e7e265553",
#             "probe_asn": "AS36925",
#             "probe_cc": "MA",
#             "report_id": "20200902T225726Z_AS36925_1v5Kidve24z4rq2QTzByB0FYuMscqcq8jTAYKgtQPD9yU4ixW3",
#             "scores": {},
#             "test_name": "ndt"
#         },
#         {
#             "anomaly": false,
#             "confirmed": false,
# ...

# %%
morocco=response['results']

# %%
data=pd.DataFrame(morocco)

# %%
data
# Out:
#      anomaly  confirmed  failure input  \
# 0      False      False    False  None
# 1      False      False    False  None
# 2      False      False    False  None
# 3      False      False    False  None
# 4      False      False    False  None
# ..       ...        ...      ...   ...
# 207    False      False    False  None
# 208    False      False    False  None
# 209    False      False    False  None
# 210    False      False    False  None
# 211    False      False    False  None
#
#                                 measurement_id measurement_start_time  \
# 0    temp-fid-00935f1c416b2f3f4fd93b4e7e265553   2020-09-02T22:57:29Z
# 1    temp-fid-00878643f01d9e9a3edeff622510be02   2020-09-02T22:57:03Z
# 2    temp-fid-001751c7ea8c8306d2a690f3200ddcb8   2020-09-02T22:34:35Z
# 3    temp-fid-00a42a08ee107c48e3cd5f5b50c47dcd   2020-09-02T22:32:37Z
# 4    temp-fid-00c082212c347505b970891e038959a3   2020-09-02T22:29:49Z
# ...

# %%
data.to_csv('csv_output/09-02/morocco_09_02.csv')
