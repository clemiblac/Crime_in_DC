# %%
#Import dependencies
import requests
import json
import pandas as pd

# %%
list_measurement="https://api.ooni.io/api/v1/measurements"

# %% [markdown]
# #### USA

# %%
url="https://api.ooni.io/api/v1/measurements?probe_cc=US&since=2020-09-01&limit=300"
response=requests.get(url).json()

# %%
print(json.dumps(response,indent=4,sort_keys=True))
# Out:
# {
#     "metadata": {
#         "count": -1,
#         "current_page": 1,
#         "limit": 300,
#         "next_url": "https://api.ooni.io/api/v1/measurements?probe_cc=US&since=2020-09-01&limit=300&offset=300",
#         "offset": 0,
#         "pages": -1,
#         "query_time": 9.50742483139038
#     },
#     "results": [
#         {
#             "anomaly": false,
#             "confirmed": false,
#             "failure": false,
#             "input": null,
#             "measurement_id": "temp-fid-00d842f39a59083a33586051a09db1ec",
#             "measurement_start_time": "2020-09-01T13:55:35Z",
#             "measurement_url": "https://api.ooni.io/api/v1/measurement/temp-fid-00d842f39a59083a33586051a09db1ec",
#             "probe_asn": "AS7922",
#             "probe_cc": "US",
#             "report_id": "20200901T135536Z_AS7922_ouiz9t5tJV0UiqN5G9phbbyTm8Dfx90nwns3C6miLiasqjgeqF",
#             "scores": {},
#             "test_name": "ndt"
#         },
#         {
# ...

# %%
us=response['results']

# %%
data=pd.DataFrame(us)

# %%
data
# Out:
#      anomaly  confirmed  failure  \
# 0      False      False    False
# 1      False      False    False
# 2      False      False    False
# 3      False      False    False
# 4      False      False    False
# ..       ...        ...      ...
# 295    False      False    False
# 296    False      False    False
# 297    False      False    False
# 298    False      False    False
# 299    False      False    False
#
#                                                  input  \
# 0                                                 None
# 1                    http://www.judaismconversion.org/
# 2                                 http://freemuse.org/
# 3                        http://www.blackjackinfo.com/
# 4                          https://www.pinknews.co.uk/
# ..                                                 ...
# 295                         http://www.freespeech.com/
# 296                              https://mastodon.xyz/
# 297                            https://www.scribd.com/
# ...

# %%
data.to_csv('csv_output/09-01/usa_09_01.csv')

# %%
min(data['measurement_start_time'])
# Out:
# '2020-09-01T12:00:26Z'

# %% [markdown]
# #### CHINA

# %%
url="https://api.ooni.io/api/v1/measurements?probe_cc=CN&since=2020-09-01&limit=300"
response=requests.get(url).json()

# %%
print(json.dumps(response,indent=4,sort_keys=True))
# Out:
# {
#     "metadata": {
#         "count": 19,
#         "current_page": 1,
#         "limit": 300,
#         "next_url": null,
#         "offset": 0,
#         "pages": 1,
#         "query_time": 1.6507840156555176
#     },
#     "results": [
#         {
#             "anomaly": false,
#             "confirmed": false,
#             "failure": false,
#             "input": "http://www.politiscales.net/",
#             "measurement_id": "temp-fid-00d9e4d12855d9e460455ce4fb60b906",
#             "measurement_start_time": "2020-09-01T12:11:34Z",
#             "measurement_url": "https://api.ooni.io/api/v1/measurement/temp-fid-00d9e4d12855d9e460455ce4fb60b906",
#             "probe_asn": "AS9808",
#             "probe_cc": "CN",
#             "report_id": "20200901T121134Z_AS9808_xyxCU4TADikFGNQZoJpfXg2Qpyq4Mq3gBn0k2zYnbSwdfkk7dv",
#             "scores": {
#                 "blocking_country": 0.0,
#                 "blocking_general": 0.0,
#                 "blocking_global": 0.0,
# ...

# %%
china=response['results']

# %%
data=pd.DataFrame(china)

# %%
data
# Out:
#     anomaly  confirmed  failure                               input  \
# 0     False      False    False        http://www.politiscales.net/
# 1     False      False     True                                None
# 2     False      False    False                                None
# 3     False      False    False                                None
# 4     False      False    False                                None
# 5     False      False    False                                None
# 6     False      False    False                                None
# 7      True      False    False                                None
# 8     False      False    False               http://www.bglad.com/
# 9      True      False    False  http://www.google.com/search?q=gay
# 10    False      False    False              https://www.baihe.com/
# 11    False      False    False      https://www.buydutchseeds.com/
# 12    False      False    False                 https://signal.org/
# ...

# %%
data.to_csv('csv_output/09-01/china_09_01.csv')

# %% [markdown]
# #### RUSSIA

# %%
url="https://api.ooni.io/api/v1/measurements?probe_cc=RU&since=2020-09-01&limit=300"
response=requests.get(url).json()

# %%
print(json.dumps(response,indent=4,sort_keys=True))
# Out:
# {
#     "metadata": {
#         "count": -1,
#         "current_page": 1,
#         "limit": 300,
#         "next_url": "https://api.ooni.io/api/v1/measurements?probe_cc=RU&since=2020-09-01&limit=300&offset=300",
#         "offset": 0,
#         "pages": -1,
#         "query_time": 8.826280117034912
#     },
#     "results": [
#         {
#             "anomaly": false,
#             "confirmed": false,
#             "failure": false,
#             "input": null,
#             "measurement_id": "temp-fid-00ff9c812fb1804d22cc73445c0e4a09",
#             "measurement_start_time": "2020-09-01T14:53:32Z",
#             "measurement_url": "https://api.ooni.io/api/v1/measurement/temp-fid-00ff9c812fb1804d22cc73445c0e4a09",
#             "probe_asn": "AS31224",
#             "probe_cc": "RU",
#             "report_id": "20200901T134426Z_AS31224_4yB07of08MLqN8DOgHbbs8xtYjGnD9Xk6XGWqA7l0UAavLT6ZP",
#             "scores": {},
#             "test_name": "ndt"
#         },
#         {
# ...

# %%
russia=response['results']

# %%
data=pd.DataFrame(russia)

# %%
data
# Out:
#      anomaly  confirmed  failure input  \
# 0      False      False    False  None
# 1      False      False    False  None
# 2      False      False    False  None
# 3      False      False    False  None
# 4      False      False    False  None
# ..       ...        ...      ...   ...
# 295    False      False    False  None
# 296    False      False    False  None
# 297    False      False    False  None
# 298    False      False    False  None
# 299    False      False    False  None
#
#                                 measurement_id measurement_start_time  \
# 0    temp-fid-00ff9c812fb1804d22cc73445c0e4a09   2020-09-01T14:53:32Z
# 1    temp-fid-00c94b32227c0dc6beef8f9c6913c68f   2020-09-01T14:01:37Z
# 2    temp-fid-0067911edf46355732fd0f00bffa3a9a   2020-09-01T13:56:57Z
# 3    temp-fid-00e1cd09d128b065b33c2eea71805790   2020-09-01T13:51:38Z
# 4    temp-fid-006fa87f991810b78a8fa218eab72314   2020-09-01T13:49:07Z
# ...

# %%
data.to_csv('csv_output/09-01/russia_09_01.csv')

# %% [markdown]
# ## Venezuala

# %%
url="https://api.ooni.io/api/v1/measurements?probe_cc=VE&since=2020-09-01&limit=300"
response=requests.get(url).json()

# %%
print(json.dumps(response,indent=4,sort_keys=True))
# Out:
# {
#     "metadata": {
#         "count": 12,
#         "current_page": 1,
#         "limit": 300,
#         "next_url": null,
#         "offset": 0,
#         "pages": 1,
#         "query_time": 0.4566464424133301
#     },
#     "results": [
#         {
#             "anomaly": false,
#             "confirmed": false,
#             "failure": false,
#             "input": null,
#             "measurement_id": "temp-fid-005bbb2c8809f20da6ba2887de30e288",
#             "measurement_start_time": "2020-09-01T12:49:11Z",
#             "measurement_url": "https://api.ooni.io/api/v1/measurement/temp-fid-005bbb2c8809f20da6ba2887de30e288",
#             "probe_asn": "AS6306",
#             "probe_cc": "VE",
#             "report_id": "20200901T124913Z_AS6306_26YW7wZkMPMn0uJ2Z7nPhPklcBO3uwTV3lRJvpcl5OFcSz72G5",
#             "scores": {},
#             "test_name": "ndt"
#         },
#         {
#             "anomaly": false,
#             "confirmed": false,
#             "failure": false,
# ...

# %%
venezuela=response['results']

# %%
data=pd.DataFrame(venezuela)

# %%
data
# Out:
#     anomaly  confirmed  failure input  \
# 0     False      False    False  None
# 1     False      False    False  None
# 2     False      False    False  None
# 3     False      False    False  None
# 4     False      False    False  None
# 5     False      False    False  None
# 6     False      False    False  None
# 7     False      False    False  None
# 8     False      False    False  None
# 9     False      False    False  None
# 10    False      False    False  None
# 11    False      False    False  None
#
#                                measurement_id measurement_start_time  \
# 0   temp-fid-005bbb2c8809f20da6ba2887de30e288   2020-09-01T12:49:11Z
# 1   temp-fid-004cd9814866ecd490feb0924f186147   2020-09-01T12:16:55Z
# 2   temp-fid-0054bbb07fa1694d41c3c5881f0be5c6   2020-09-01T11:41:47Z
# 3   temp-fid-008985dbb4a38b33455a7df911386705   2020-09-01T10:31:08Z
# 4   temp-fid-00cedfcb38d134c8ff7d612a016ab0c4   2020-09-01T09:50:21Z
# ...

# %%
data.to_csv('csv_output/09-01/venezuela_09_01.csv')

# %% [markdown]
# ## Morocco

# %%
url="https://api.ooni.io/api/v1/measurements?probe_cc=MA&since=2020-09-01&limit=300"
response=requests.get(url).json()

# %%
print(json.dumps(response,indent=4,sort_keys=True))
# Out:
# {
#     "metadata": {
#         "count": 46,
#         "current_page": 1,
#         "limit": 300,
#         "next_url": null,
#         "offset": 0,
#         "pages": 1,
#         "query_time": 7.700197458267212
#     },
#     "results": [
#         {
#             "anomaly": false,
#             "confirmed": false,
#             "failure": false,
#             "input": null,
#             "measurement_id": "temp-fid-002f9ea6276ea7937cb6a96cafa3289c",
#             "measurement_start_time": "2020-09-01T13:41:44Z",
#             "measurement_url": "https://api.ooni.io/api/v1/measurement/temp-fid-002f9ea6276ea7937cb6a96cafa3289c",
#             "probe_asn": "AS36903",
#             "probe_cc": "MA",
#             "report_id": "20200901T134144Z_AS36903_S2QKSRgqikqE0lRbbUQk99YeQBELSiQqwOlsafUZ2iI3ORAMhx",
#             "scores": {},
#             "test_name": "ndt"
#         },
#         {
#             "anomaly": false,
#             "confirmed": false,
#             "failure": false,
# ...

# %%
morocco=response['results']

# %%
data=pd.DataFrame(morocco)

# %%
data
# Out:
#     anomaly  confirmed  failure input  \
# 0     False      False    False  None
# 1     False      False    False  None
# 2     False      False    False  None
# 3     False      False    False  None
# 4     False      False    False  None
# 5     False      False    False  None
# 6     False      False    False  None
# 7     False      False    False  None
# 8     False      False    False  None
# 9     False      False    False  None
# 10    False      False    False  None
# 11    False      False    False  None
# 12    False      False    False  None
# 13    False      False    False  None
# 14    False      False    False  None
# 15    False      False    False  None
# 16    False      False    False  None
# 17    False      False    False  None
# 18    False      False    False  None
# 19    False      False    False  None
# 20    False      False    False  None
# 21    False      False    False  None
# 22    False      False    False  None
# ...

# %%
data.to_csv('csv_output/09-01/morocco_09_01.csv')
