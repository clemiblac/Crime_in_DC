# %%
#Import dependencies
import requests
import json
import pandas as pd

# %%
list_measurement="https://api.ooni.io/api/v1/measurements"

# %% [markdown]
# #### USA

# %%
url="https://api.ooni.io/api/v1/measurements?probe_cc=US&since=2020-08-29&limit=300"
response=requests.get(url).json()

# %%
print(json.dumps(response,indent=4,sort_keys=True))
# Out:
# {
#     "metadata": {
#         "count": -1,
#         "current_page": 1,
#         "limit": 300,
#         "next_url": "https://api.ooni.io/api/v1/measurements?probe_cc=US&since=2020-08-28&limit=300&offset=300",
#         "offset": 0,
#         "pages": -1,
#         "query_time": 39.65655779838562
#     },
#     "results": [
#         {
#             "anomaly": false,
#             "confirmed": false,
#             "failure": false,
#             "input": null,
#             "measurement_id": "temp-fid-0074cee9db1d48f4d4cca277c4e30e79",
#             "measurement_start_time": "2020-08-30T17:06:43Z",
#             "measurement_url": "https://api.ooni.io/api/v1/measurement/temp-fid-0074cee9db1d48f4d4cca277c4e30e79",
#             "probe_asn": "AS0",
#             "probe_cc": "US",
#             "report_id": "20200828T170711Z_AS0_EVPmGXUEStSI8LCFkuF90dzgZBbzlJRxUmAQw6nm4cN9sGDYfd",
#             "scores": {},
#             "test_name": "ndt"
#         },
#         {
# ...

# %%
us=response['results']

# %%
data=pd.DataFrame(us)

# %%
data
# Out:
#      anomaly  confirmed  failure                                input  \
# 0      False      False    False                                 None
# 1      False      False    False                                 None
# 2      False      False    False                                 None
# 3       True      False    False                                 None
# 4      False      False    False                                 None
# ..       ...        ...      ...                                  ...
# 295    False      False    False                                 None
# 296    False      False    False            https://sites.google.com/
# 297    False      False    False               http://pingomatic.com/
# 298    False      False    False  https://friends.walla.co.il/#/login
# 299    False      False    False                                 None
#
#                                 measurement_id measurement_start_time  \
# ...

# %%
data.to_csv('csv_output/08-29/usa_08_29.csv')

# %%
min(data['measurement_start_time'])
# Out:
# '2020-08-28T16:05:35Z'

# %% [markdown]
# #### CHINA

# %%
url="https://api.ooni.io/api/v1/measurements?probe_cc=CN&since=2020-08-29&limit=300"
response=requests.get(url).json()

# %%
print(json.dumps(response,indent=4,sort_keys=True))
# Out:
# {
#     "metadata": {
#         "count": 65,
#         "current_page": 1,
#         "limit": 300,
#         "next_url": null,
#         "offset": 0,
#         "pages": 1,
#         "query_time": 2.488935947418213
#     },
#     "results": [
#         {
#             "anomaly": false,
#             "confirmed": false,
#             "failure": false,
#             "input": null,
#             "measurement_id": "temp-fid-0090dcd358046db4a7aec7af8381fc5d",
#             "measurement_start_time": "2020-08-28T17:18:23Z",
#             "measurement_url": "https://api.ooni.io/api/v1/measurement/temp-fid-0090dcd358046db4a7aec7af8381fc5d",
#             "probe_asn": "AS45102",
#             "probe_cc": "CN",
#             "report_id": "20200828T171823Z_AS45102_kzppA1FQGffox7ylQKzEY26ENkAMeGW3TxpClVkpf079vRS2K7",
#             "scores": {
#                 "blocking_country": 0.0,
#                 "blocking_general": 0.0,
#                 "blocking_global": 0.0,
# ...

# %%
china=response['results']

# %%
data=pd.DataFrame(china)

# %%
data
# Out:
#     anomaly  confirmed  failure                     input  \
# 0     False      False    False                      None
# 1      True      False    False                      None
# 2     False      False    False                      None
# 3     False      False    False                      None
# 4      True      False    False                      None
# ..      ...        ...      ...                       ...
# 60    False      False    False  https://sputniknews.com/
# 61    False      False    False                      None
# 62    False      False    False                      None
# 63    False      False    False                      None
# 64    False      False    False                      None
#
#                                measurement_id measurement_start_time  \
# 0   temp-fid-0090dcd358046db4a7aec7af8381fc5d   2020-08-28T17:18:23Z
# 1   temp-fid-0078104f50ae29985c8f5e85f8479ad3   2020-08-28T17:18:16Z
# ...

# %%
data.to_csv('csv_output/08-29/china_08_29.csv')

# %% [markdown]
# #### RUSSIA

# %%
url="https://api.ooni.io/api/v1/measurements?probe_cc=RU&since=2020-08-29&limit=300"
response=requests.get(url).json()

# %%
print(json.dumps(response,indent=4,sort_keys=True))
# Out:
# {
#     "metadata": {
#         "count": -1,
#         "current_page": 1,
#         "limit": 300,
#         "next_url": "https://api.ooni.io/api/v1/measurements?probe_cc=RU&since=2020-08-28&limit=300&offset=300",
#         "offset": 0,
#         "pages": -1,
#         "query_time": 9.225203514099121
#     },
#     "results": [
#         {
#             "anomaly": false,
#             "confirmed": false,
#             "failure": false,
#             "input": null,
#             "measurement_id": "temp-id-432092012",
#             "measurement_start_time": "2020-08-30T09:39:09Z",
#             "measurement_url": "https://api.ooni.io/api/v1/measurement/temp-id-432092012",
#             "probe_asn": "AS12958",
#             "probe_cc": "RU",
#             "report_id": "20200810T093909Z_AS12958_tFmComZMRav9ua56eMMlEtVGyA2lPLAoZI3EC7SP2us6CXlsNp",
#             "scores": {},
#             "test_name": "ndt"
#         },
#         {
#             "anomaly": false,
# ...

# %%
russia=response['results']

# %%
data=pd.DataFrame(russia)

# %%
data
# Out:
#      anomaly  confirmed  failure input  \
# 0      False      False    False  None
# 1      False      False    False  None
# 2      False      False    False  None
# 3      False      False    False  None
# 4      False      False    False  None
# ..       ...        ...      ...   ...
# 295    False      False    False  None
# 296    False      False    False  None
# 297    False      False    False  None
# 298    False      False    False  None
# 299    False      False    False  None
#
#                                 measurement_id measurement_start_time  \
# 0                            temp-id-432092012   2020-08-30T09:39:09Z
# 1    temp-fid-00f7a91270bda3839ba6170042be3756   2020-08-29T12:25:49Z
# 2    temp-fid-00e77227dccb4c336d3540ffb9827e6a   2020-08-29T12:06:40Z
# 3    temp-fid-00903de74911f6ba54dac8e676b93fad   2020-08-29T12:05:44Z
# 4                            temp-id-436523764   2020-08-28T19:19:57Z
# ...

# %%
data.to_csv('csv_output/08-29/russia_08_29.csv')

# %% [markdown]
# ## Venezuala

# %%
url="https://api.ooni.io/api/v1/measurements?probe_cc=VE&since=2020-08-29&limit=300"
response=requests.get(url).json()

# %%
print(json.dumps(response,indent=4,sort_keys=True))
# Out:
# {
#     "metadata": {
#         "count": 28,
#         "current_page": 1,
#         "limit": 300,
#         "next_url": null,
#         "offset": 0,
#         "pages": 1,
#         "query_time": 0.4312102794647217
#     },
#     "results": [
#         {
#             "anomaly": false,
#             "confirmed": false,
#             "failure": false,
#             "input": null,
#             "measurement_id": "temp-fid-004918f0868d3e23c5b607f36bec6615",
#             "measurement_start_time": "2020-08-28T17:17:56Z",
#             "measurement_url": "https://api.ooni.io/api/v1/measurement/temp-fid-004918f0868d3e23c5b607f36bec6615",
#             "probe_asn": "AS27889",
#             "probe_cc": "VE",
#             "report_id": "20200828T171947Z_AS27889_kmf4L1nvZkPh63NVjD5YrbMkJoT591j3AE9XmW4wcrDfBnzGZe",
#             "scores": {},
#             "test_name": "ndt"
#         },
#         {
#             "anomaly": false,
#             "confirmed": false,
# ...

# %%
venezuela=response['results']

# %%
data=pd.DataFrame(venezuela)

# %%
data
# Out:
#     anomaly  confirmed  failure                  input  \
# 0     False      False    False                   None
# 1     False      False    False                   None
# 2     False      False    False                   None
# 3     False      False    False                   None
# 4     False      False    False                   None
# 5     False      False    False                   None
# 6     False      False    False                   None
# 7     False      False    False                   None
# 8     False      False    False                   None
# 9     False      False    False                   None
# 10    False      False    False                   None
# 11    False      False    False                   None
# 12    False      False    False                   None
# 13    False      False    False                   None
# 14    False      False    False                   None
# 15    False      False    False                   None
# ...

# %%
data.to_csv('csv_output/08-29/venezuela_08_29.csv')

# %% [markdown]
# ## Morocco

# %%
url="https://api.ooni.io/api/v1/measurements?probe_cc=MA&since=2020-08-29&limit=300"
response=requests.get(url).json()

# %%
print(json.dumps(response,indent=4,sort_keys=True))
# Out:
# {
#     "metadata": {
#         "count": 130,
#         "current_page": 1,
#         "limit": 300,
#         "next_url": null,
#         "offset": 0,
#         "pages": 1,
#         "query_time": 7.592998504638672
#     },
#     "results": [
#         {
#             "anomaly": false,
#             "confirmed": false,
#             "failure": false,
#             "input": null,
#             "measurement_id": "temp-fid-00bb8e621bb1b6b185afa31ad91c36bc",
#             "measurement_start_time": "2020-08-28T17:47:23Z",
#             "measurement_url": "https://api.ooni.io/api/v1/measurement/temp-fid-00bb8e621bb1b6b185afa31ad91c36bc",
#             "probe_asn": "AS36903",
#             "probe_cc": "MA",
#             "report_id": "20200828T174721Z_AS36903_6yAYr1Kbh3rqcHJNrz6GeP0lZzYgpF7gl1ks2APt4wPLCoUr2S",
#             "scores": {
#                 "blocking_country": 0.0,
#                 "blocking_general": 0.0,
#                 "blocking_global": 0.0,
# ...

# %%
morocco=response['results']

# %%
data=pd.DataFrame(morocco)

# %%
data
# Out:
#      anomaly  confirmed  failure input  \
# 0      False      False    False  None
# 1      False      False    False  None
# 2      False      False    False  None
# 3      False      False    False  None
# 4      False      False    False  None
# ..       ...        ...      ...   ...
# 125    False      False    False  None
# 126    False      False    False  None
# 127    False      False    False  None
# 128    False      False    False  None
# 129    False      False    False  None
#
#                                 measurement_id measurement_start_time  \
# 0    temp-fid-00bb8e621bb1b6b185afa31ad91c36bc   2020-08-28T17:47:23Z
# 1    temp-fid-00ec69fca933262a42de842d2dc9d23a   2020-08-28T17:47:20Z
# 2    temp-fid-00532de93547d9f0ac665aa20122d1b7   2020-08-28T17:46:48Z
# 3    temp-fid-003c5bb0de6dc0af581fb13a9a0d3a3c   2020-08-28T17:46:22Z
# 4    temp-fid-003c67a1f60ec0a8f0e07fd04de642c0   2020-08-28T17:18:38Z
# ...

# %%
data.to_csv('csv_output/08-29/morocco_08_29.csv')
