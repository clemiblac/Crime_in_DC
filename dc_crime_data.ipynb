# %%
import pandas as pd
import json
import sqlalchemy

# %%
data_1 = pd.read_csv('Crime_Incidents_in_2015.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-33686bdd29f5> in <module>
# ----> 1 data_1 = pd.read_csv('Crime_Incidents_in_2015.csv')
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# ...

# %%
data_1

# %%
data_2 = pd.read_csv('Crime_Incidents_in_2016.csv')

engine = connect.

# %%
data_2

# %%
data_3 = pd.read_csv('Crime_Incidents_in_2017.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-adcca2fce1ba> in <module>
# ----> 1 data_3 = pd.read_csv('Crime_Incidents_in_2017.csv')
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# ...

# %%
data_3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-0b22a9d96525> in <module>
# ----> 1 data_3
#
# NameError: name 'data_3' is not defined

# %%
data_4 = pd.read_csv('Crime_Incidents_in_2018.csv')

# %%
data_4
# Out:
#                X          Y       CCN              REPORT_DAT     SHIFT  \
# 0     -76.972215  38.852618   7006630  2018/07/26 00:00:00+00  MIDNIGHT
# 1     -77.074960  38.912611  10954295  2018/04/05 21:17:59+00   EVENING
# 2     -76.978422  38.899255  12146972  2018/07/31 00:00:00+00  MIDNIGHT
# 3     -76.929229  38.901839  16208156  2018/01/05 00:00:00+00  MIDNIGHT
# 4     -76.965614  38.851265  17003498  2018/03/20 00:00:00+00  MIDNIGHT
# ...          ...        ...       ...                     ...       ...
# 33749 -77.004828  38.835153  18067093  2018/05/04 00:00:00+00  MIDNIGHT
# 33750 -77.020268  38.938811  18067757  2018/04/28 14:58:51+00       DAY
# 33751 -77.020268  38.938811  18067757  2018/04/28 14:58:51+00       DAY
# 33752 -77.005900  38.837613  18070920  2018/05/03 00:00:00+00  MIDNIGHT
# 33753 -77.005900  38.837613  18070920  2018/05/03 00:00:00+00  MIDNIGHT
#
#        METHOD    OFFENSE                                        BLOCK  \
# ...

# %%
data_5 = pd.read_csv('Crime_Incidents_in_2019.csv')

# %%
data_5
# Out:
#                X          Y       CCN              REPORT_DAT     SHIFT  \
# 0     -77.024836  38.939216  20400003  2019/12/27 14:26:12+00       DAY
# 1     -76.993213  38.893582  20400005  2019/12/28 22:46:44+00   EVENING
# 2     -76.977259  38.894039  20400007  2019/12/19 04:17:35+00  MIDNIGHT
# 3     -76.981503  38.886248  20400008  2019/12/03 19:13:01+00   EVENING
# 4     -76.984578  38.898121  20400010  2019/12/18 18:54:43+00   EVENING
# ...          ...        ...       ...                     ...       ...
# 33904 -76.987846  38.867268  19227554  2019/12/22 16:20:42+00   EVENING
# 33905 -76.931270  38.877590  19227556  2019/12/22 18:11:58+00   EVENING
# 33906 -77.040249  38.924294  19227558  2019/12/22 16:21:30+00   EVENING
# 33907 -77.041671  38.910763  19227559  2019/12/22 16:14:58+00   EVENING
# 33908 -76.946581  38.868887  20035314  2019/05/19 20:57:47+00   EVENING
#
#        METHOD                     OFFENSE  \
# 0      OTHERS                THEFT F/AUTO
# ...
